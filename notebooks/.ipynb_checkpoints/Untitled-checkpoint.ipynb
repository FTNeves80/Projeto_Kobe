# %%
print("teste")
# Out:
# teste

# %%
import pandas as pd

# %%
raw_data = catalog.load('dataset_kobe_dev.parquet')



#train:
#  type: pandas.ParquetDataset
#  filepath: data/01_raw/dataset_kobe_dev.parquet

#train:
#  type: pandas.ParquetDataset
#  filepath: data/01_raw/dataset_kobe_prod.parquet
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱  1 raw_data = catalog.load('dataset_kobe_dev.parquet')                                         │
# │    2                                                                                             │
# │    3                                                                                             │
# │    4                                                                                             │
# │                                                                                                  │
# │ C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\kedro\io\data_catalog.py │
# │ :399 in load                                                                                     │
# │                                                                                                  │
# │ C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\kedro\io\data_catalog.py │
# │ :359 in _get_dataset                                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# DatasetNotFoundError: Dataset 'dataset_kobe_dev.parquet' not found in the catalog
